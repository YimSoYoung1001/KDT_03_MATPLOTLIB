# %%
import pandas as pd

# %%
file = '../DATA/repo.json'
file = pd.read_json(file)
file
# Out:
#      id                   node_id                    name  \
# 0     1      MDEwOlJlcG9zaXRvcnkx                    grit
# 1    26  MDEwOlJlcG9zaXRvcnkyNg==               merb-core
# 2    27  MDEwOlJlcG9zaXRvcnkyNw==                rubinius
# 3    28  MDEwOlJlcG9zaXRvcnkyOA==                     god
# 4    29  MDEwOlJlcG9zaXRvcnkyOQ==               jsawesome
# ..  ...                       ...                     ...
# 95  364  MDEwOlJlcG9zaXRvcnkzNjQ=      acts_as_geocodable
# 96  365  MDEwOlJlcG9zaXRvcnkzNjU=           acts_as_money
# 97  367  MDEwOlJlcG9zaXRvcnkzNjc=        calendar_builder
# 98  368  MDEwOlJlcG9zaXRvcnkzNjg=  clear_empty_attributes
# 99  369  MDEwOlJlcG9zaXRvcnkzNjk=           css_naked_day
#
#                                 full_name  private  \
# 0                            mojombo/grit    False
# 1                        wycats/merb-core    False
# 2                       rubinius/rubinius    False
# 3                             mojombo/god    False
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 46 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    int64
#  1   node_id            100 non-null    object
#  2   name               100 non-null    object
#  3   full_name          100 non-null    object
#  4   private            100 non-null    bool
#  5   owner              100 non-null    object
#  6   html_url           100 non-null    object
#  7   description        97 non-null     object
#  8   fork               100 non-null    bool
#  9   url                100 non-null    object
#  10  forks_url          100 non-null    object
#  11  keys_url           100 non-null    object
#  12  collaborators_url  100 non-null    object
#  13  teams_url          100 non-null    object
#  14  hooks_url          100 non-null    object
#  15  issue_events_url   100 non-null    object
# ...
